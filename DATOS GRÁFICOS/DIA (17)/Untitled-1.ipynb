# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import networkx as nx

# Leer los datos del archivo CSV
df = pd.read_csv('evolucion_de_los_votos_que_españa_ha_recibido_en_eurovision.csv', encoding='latin-1')

# Crear un gráfico dirigido desde el DataFrame
G = nx.from_pandas_edgelist(df, 'ï»¿From', 'To', create_using=nx.DiGraph())

# Obtener el número de votos que recibe cada país
vote_counts = df['To'].value_counts().to_dict()

# Crear un mapeo de tamaño de nodo basado en el número de votos
min_node_size = 100  # Tamaño mínimo para los nodos sin votos
node_size = [max(vote_counts.get(node, 0) * 100, min_node_size) for node in G.nodes()]

# Dibujar el gráfico de red con disposición Fruchterman-Reingold y mayor dispersión
plt.figure(figsize=(12, 8))
pos = nx.spring_layout(G, k=0.2)  # Usar disposición Fruchterman-Reingold con mayor dispersión (k más pequeño)
nx.draw(G, pos, with_labels=True, node_size=node_size, node_color='skyblue', edge_color='gray', font_size=8, arrowsize=12)

# Añadir etiquetas de país
pos_labels = {key: (x, y + 0.05) for key, (x, y) in pos.items()}  # Mover las etiquetas hacia arriba

plt.title('Países que recibieron 12 puntos en la votación de Eurovisión 2023')
plt.axis('off')  # Ocultar ejes
plt.tight_layout()  # Ajustar el diseño
plt.show()
# Out:
# C:\Users\radir\AppData\Local\Temp\ipykernel_4412\109176659.py:30: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout()  # Ajustar el diseño

# %%
df.columns
# Out:
# Index(['ï»¿From', 'To'], dtype='object')
